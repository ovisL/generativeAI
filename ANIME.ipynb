# %% [markdown]
# <a href="https://colab.research.google.com/github/ovisL/generativeAI/blob/main/ANIME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANIME image generative AI
# - stable diffusion
# - https://huggingface.co/hakurei/waifu-diffusion

# %% [markdown]
# ## install

# %%
#@title
# !pip install --upgrade -qq git+https://github.com/huggingface/diffusers.git transformers accelerate scipy xformers gradio translate
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    'hakurei/waifu-diffusion',
    torch_dtype=torch.float32
).to('cuda')
# Out:
# ERROR: Operation cancelled by user

# %%
def generate(prompt_list) :
    negative_prompt_list = [
        'lowres',
        '(bad anatomy, bad hands:1.1)',
        'text',
        'error',
        'missing fingers',
        'extra digit',
        'fewer digits',
        'cropped',
        'worst quality',
        'low quality',
        'normal quality',
        'jpeg artifacts',
        'signature',
        'watermark',
        'username',
        'blurry',
        'artist name',
        'b&w',
        'weird colors',
        '(cartoon, 3d, bad art, poorly drawn, close up, blurry:1.5)',
        '(disfigured, deformed, extra limbs:1.5)'
    ]
    negative_prompt = ', '.join(negative_prompt_list)
    prompt = ', '.join(prompt_list)

    seed = 12

    num_inference_steps = 50 # 25
    guidance_scale = 12 # 7.5
    width = 768
    height = 512

    image = pipe(
        prompt,
        negative_prompt = negative_prompt,
        num_inference_steps = num_inference_steps,
        guidance_scale = guidance_scale,
        width = width,
        height = height,
        generator = torch.Generator('cuda').manual_seed(seed) if seed != 0 else None
    ).images[0]
    return image

# %%
prompt_list = [
    '1girl',
    '(red hair)',
    'black eyes',
    'beautiful eyes',
    '((black red-crowned crane shape necklace))',
    '((extremely delicate and beautiful girl))',
    '((Silicon Valley))',
    'detailed sky',
    'masterpiece',
    'best quality',
    'CG',
    'wallpaper',
    'HDR',
    'high quality',
    'high definition',
    'extremely detailed',
    'looking at viewer',
]
output = generate(prompt_list)
output.save("1.png")
output.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F81B66BEAD0>

# %%
prompt_list2 = [
    '1girl',
    'gradation red hair',
    'black eyes',
    'beautiful eyes',
    '((crane-beak necklace))',
    '((extremely delicate and beautiful girl))',
    # '((Silicon Valley))',
    'detailed sky',
    'masterpiece',
    'best quality',
    'CG',
    'wallpaper',
    'HDR',
    'high quality',
    'high definition',
    'extremely detailed',
    'looking at viewer',
]
output = generate(prompt_list2)
output.save("2.png")
output.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F81B66BE1D0>

# %%
prompt_list3 = [
    '1girl',
    'gradation red hair',
    'red eyes',
    'beautiful eyes',
    'crane-beak shape necklace',
    '((extremely delicate and beautiful girl))',
    # '((Silicon Valley))',
    'detailed sky',
    'masterpiece',
    'best quality',
    'CG',
    'wallpaper',
    'HDR',
    'high quality',
    'high definition',
    'extremely detailed',
    'looking at viewer',
]
output = generate(prompt_list3)
output.save("3.png")
output.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F81B66BC3D0>

# %%
prompt_list4 = [
    '1girl',
    'gradation red hair',
    'red eyes',
    'beautiful eyes',
    'crane-beak cap',
    '((extremely delicate and beautiful girl))',
    # '((Silicon Valley))',
    'detailed sky',
    'masterpiece',
    'best quality',
    'CG',
    'wallpaper',
    'HDR',
    'high quality',
    'high definition',
    'extremely detailed',
    'looking at viewer',
]
output = generate(prompt_list4)
output.save("4.png")
output.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F81AEB32530>
